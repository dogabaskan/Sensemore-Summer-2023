# %%
import pandas as pd

df = pd.read_csv('telemetry_watch.csv')
df
# Out:
#               created_at    GRMS_X    GRMS_Y    GRMS_Z    VRMS_X    VRMS_Y
# 0    2022-11-07 08:26:41  0.006375  0.005954  0.007951  0.151145  0.110155  \
# 1    2022-11-09 11:04:48  0.006427  0.005864  0.007928  0.115720  0.074589
# 2    2022-11-09 12:14:47  0.006403  0.005863  0.007943  0.132268  0.104184
# 3    2022-11-09 13:24:57  0.006389  0.005874  0.008031  0.091605  0.094042
# 4    2022-11-09 14:34:26  0.006411  0.005827  0.007912  0.113345  0.080807
# ..                   ...       ...       ...       ...       ...       ...
# 431  2022-11-30 05:11:09  0.006391  0.005834  0.007859  0.107086  0.111417
# 432  2022-11-30 06:20:24  0.006408  0.005813  0.007911  0.124697  0.089609
# 433  2022-11-30 07:29:55  0.006417  0.005836  0.007882  0.101552  0.106846
# 434  2022-11-30 08:39:24  0.006364  0.005902  0.007834  0.126536  0.080714
# 435  2022-11-30 09:48:55  0.006417  0.005855  0.007961  0.134294  0.070170
#
#        VRMS_Z  temperature
# 0    0.125084    27.559999
# ...

# %%
import numpy as np 

from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()

data= df['temperature'].values.reshape(-1,1)
data = sc.fit_transform(data)
df['temperature']=data

mean = np.min(df['GRMS_Z'])
mean
# Out:
# 0.0078199645504355

# %%
import plotly as py
from plotly.offline import init_notebook_mode, iplot, plot
import plotly.graph_objs as go

# Creating trace1
trace1 = go.Scatter ( y = df.temperature, mode = "lines", 
                     marker = dict(color= 'rgba(16,112,2,0.8)'))

trace2 = go.Scatter( y = df.GRMS_Z, mode = "lines", marker = dict(color = 'rgba(28,55,2,0.8)')) 


data = [trace1]

layout = dict(title = 'Temperature', 
              xaxis = dict(ticklen= 5 , zeroline = False))

fig = dict(data= data ,layout = layout)
iplot(fig)
